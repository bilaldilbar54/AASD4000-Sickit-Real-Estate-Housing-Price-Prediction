# %% [markdown]
# # Task6: Predicting Real Estate House Prices

# %% [markdown]
# ## This task is provided to test your understanding of building a Linear Regression model for a provided dataset

# %% [markdown]
# ### Dataset: Real_estate.csv

# %% [markdown]
# ### Import the necessary libraries
# #### Hint: Also import seaborn

# %%
import matplotlib
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Read the csv data into a pandas dataframe and display the first 5 samples

# %%
# Reading Dataset
url = '/Users/bilaldilbar/Documents/GeorgeBrown/Sem1/AASD4000/Assignments/Task 6/Real Estate Dataset/Real estate.csv'
real_estate_data = pd.read_csv(url, sep = ',')
real_estate_data.head(5)
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# 3     24.98746     121.54391                        54.8
# 4     24.97937     121.54245                        43.1

# %% [markdown]
# ### Show more information about the dataset

# %%
real_estate_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %% [markdown]
# ### Find how many samples are there and how many columns are there in the dataset

# %%
real_estate_data.shape
# Out:
# (414, 8)

# %% [markdown]
# ### What are the features available in the dataset?

# %%
real_estate_data.columns
# Out:
# Index(['No', 'X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %% [markdown]
# ### Check if any features have missing data

# %%
real_estate_data.isna().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %% [markdown]
# ### Group all the features as dependent features in X

# %%
X = real_estate_data.iloc[:,:-1]
X
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ..                                      ...                              ...
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude
# 0       24.98298     121.54024
# 1       24.98034     121.53951
# 2       24.98746     121.54391
# 3       24.98746     121.54391
# 4       24.97937     121.54245
# ..           ...           ...
# 409     24.94155     121.50381
# 410     24.97433     121.54310
# 411     24.97923     121.53986
# 412     24.96674     121.54067
# 413     24.97433     121.54310
#
# [414 rows x 7 columns]

# %% [markdown]
# ### Group feature(s) as independent features in y

# %%
y = real_estate_data.iloc[:,-1]
y
# Out:
# 0      37.9
# 1      42.2
# 2      47.3
# 3      54.8
# 4      43.1
#        ...
# 409    15.4
# 410    50.0
# 411    40.6
# 412    52.5
# 413    63.9
# Name: Y house price of unit area, Length: 414, dtype: float64

# %% [markdown]
# ### Split the dataset into train and test data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.6)

# %% [markdown]
# ### Choose the model (Linear Regression)

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Create an Estimator object

# %%
model_linear_reg = LinearRegression()

# %% [markdown]
# ### Train the model

# %%
model_linear_reg.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# ### Apply the model

# %%
y_pred = model_linear_reg.predict(X)
y_pred
# Out:
# array([47.89494828, 48.56266359, 49.48549608, 49.06033833, 46.89537276,
#        31.91889851, 39.33884835, 47.54002053,  9.81655865, 35.48386229,
#        34.29401738, 53.78979552, 41.54535896, 27.67273277, 46.25647334,
#        38.73649247, 51.43047277, 37.9292868 , 47.38089493, 48.26799893,
#        35.95766929, 50.11138559, 29.50341213, 48.5161202 , 35.50368053,
#        32.63559946, 46.82956086, 42.76561856, 43.36789538, 46.32719978,
#        13.89809241, 41.15359321, 31.29576969, 47.00535857, 47.72827054,
#        33.70165743, 31.12724096, 31.45055473, 45.00438468, 46.47306013,
#        15.01052845, 17.07419178, 37.12270337, 40.76168072, 48.22815789,
#        40.29546715, 47.30437819, 38.02779522, 13.16548441, 10.05136704,
#        42.34410669, 24.32725969, 35.39205449, 42.15990131, 46.01959847,
#        23.86067762, 43.89609878, 46.45669327, 14.0061475 , 41.22718249,
#        34.55078751, 50.88818913, 30.24001441, 48.18696556, 33.68817154,
#        44.03927002, 47.57742051, 47.58869518, 43.67261577, 45.65208957,
#        54.76629818, 35.51034432, 45.50794239, 15.6859821 , 53.26095864,
#        47.79082526, 53.52309421, 31.37924952, 32.57481505, 43.16676242,
#        36.16883426, 50.79701913, 36.9547949 , 47.75324821, 47.04074981,
#        30.67741002, 45.21625484, 38.75913878, 42.51466978, 44.88991696,
#        30.37617435, 41.75333582, 33.67049306, 14.93513112, 47.32401789,
#        44.95692717, 29.02511658, 31.06705967, 32.69618137, 34.29406952,
#        45.09054545, 42.03855504, 20.65811675, 46.72201172, 24.79144224,
#        31.61798325, 40.19083191, 44.28679657, 45.91065467, 46.81118105,
#        35.82554323, 45.53747765, 37.24834958, 54.41579206, 35.11525237,
#        11.63335437, 41.45581076, 39.81105481, 43.61206926, 30.47863401,
#        39.28928679, 48.28864416, 44.18931987, 33.78438948, 12.84370049,
#        23.99893288, 12.04949353, 32.87535102, 43.01309772, 39.06466567,
#        41.48687004, 37.02784194, 35.17133461, 41.64365353, 50.08938108,
#        34.04357246, 37.97929027, 49.38017962, 42.14943189, 27.7906669 ,
#        39.75908064, 33.9922189 , 10.04209091, 46.65869239, 42.9556017 ,
#        40.69815138, 32.37927263, 25.89210333, 35.81897617, 31.52701826,
#        48.41881747, 39.49907544, 52.23796284, 47.34924152, 28.36167868,
#        45.08158447, 39.59771905, 43.78230328, 49.08747827, 41.63881627,
#        29.59936196, 25.38495347, 30.07693486, 39.92029811, 27.05782984,
#        43.24688438, 44.3300641 , 38.97167134, 43.34746698, 47.57541992,
#        29.94968396, 33.53919606, 48.67162339, 39.85025044, 50.54759606,
#        46.6595728 , 54.22700224, 13.24250319, 36.35602819, 12.22189473,
#        50.65676154, 40.45487558, 30.74485985, 33.86514036, 39.85574227,
#        44.16024904, 31.05324567, 37.47978792, 41.60709372, 15.24500036,
#        38.70022607, 27.26685608, 44.4856823 , 33.46013903, 39.20678333,
#        40.19194731, 32.47335135, 38.72953552, 44.1291934 , 45.95039226,
#        36.99902313, 48.9133769 , 25.75798374, 31.24696162, 13.65744228,
#        49.16290573, 46.07582217, 43.91773036, 53.13924719])

# %% [markdown]
# ### Display the coefficients

# %%
model_linear_reg.coef_
# Out:
# array([-3.59350128e-03,  5.07908732e+00, -2.70841959e-01, -4.52079011e-03,
#         1.12927749e+00,  2.24672892e+02, -1.44235635e+01])

# %% [markdown]
# ### Find how well the trained model did with testing data

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y, y_pred)

r2
# Out:
# 0.58336326163246

# %% [markdown]
# ### Plot House Age Vs Price
# #### Hint: Use regplot in sns

# %%
sns.regplot(x='X2 house age', y='Y house price of unit area', data=real_estate_data)
# Out:
# <Axes: xlabel='X2 house age', ylabel='Y house price of unit area'>

# %% [markdown]
# ### Plot Distance to MRT station Vs Price

# %%
sns.regplot(x='X3 distance to the nearest MRT station', y='Y house price of unit area', data=real_estate_data)
# Out:
# <Axes: xlabel='X3 distance to the nearest MRT station', ylabel='Y house price of unit area'>

# %% [markdown]
# ### Plot Number of Convienience Stores Vs Price

# %%
sns.regplot(x='X4 number of convenience stores', y='Y house price of unit area', data=real_estate_data)
# Out:
# <Axes: xlabel='X4 number of convenience stores', ylabel='Y house price of unit area'>
